# %%
from metaflow import Flow
from color_brains.model.rgb_model_flow import RGBModelFlow
from color_brains.data_enrichment.rgb_feature_enrichment_flow import RGBFeatureEnrichmentFlow
import pandas as pdz
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.colors import LinearSegmentedColormap

# %%
model_flow = Flow(RGBModelFlow.__name__)
latest_run = model_flow.latest_successful_run
xgb_reg = latest_run.data.xgb_reg
dependent_variables = latest_run.data.x_cols
dataset = Flow(RGBFeatureEnrichmentFlow.__name__).latest_run.data.dataset
cmap_name_col = Flow(RGBFeatureEnrichmentFlow.__name__).latest_run.data.cmap_column_name
"""
complete failure - 
Run('RGBModelFlow/1726322386924671')

moderate success
Run('RGBModelFlow/1727060336171372')

worse
Run('RGBModelFlow/1728076916444087')

"""
dependent_variables
current_rgb = ['red', 'green', 'blue']
start_rgb = [c for c in dependent_variables if c.startswith('start')]
previous_rgb = [c for c in dependent_variables if c.startswith('previous')]
end_rgb = [c for c in dependent_variables if c.startswith('end')]
model_flow.latest_successful_run
# Out:
# Run('RGBModelFlow/1728077973495543')

# %%
dataset
# Out:
#                  colormap_name       red     green      blue  previous_red  \
# 513         sequential.Purples  0.986636  0.982591  0.991173      0.988235
# 514         sequential.Purples  0.985037  0.980869  0.990188      0.986636
# 515         sequential.Purples  0.983437  0.979146  0.989204      0.985037
# 516         sequential.Purples  0.981838  0.977424  0.988220      0.983437
# 517         sequential.Purples  0.980238  0.975702  0.987236      0.981838
# ...                        ...       ...       ...       ...           ...
# 63482  scientific.Oleron_256_r  0.129412  0.180392  0.380392      0.137255
# 63483  scientific.Oleron_256_r  0.125490  0.172549  0.372549      0.129412
# 63484  scientific.Oleron_256_r  0.117647  0.168627  0.368627      0.125490
# 63485  scientific.Oleron_256_r  0.113725  0.160784  0.360784      0.117647
# 63486  scientific.Oleron_256_r  0.105882  0.156863  0.356863      0.113725
#
#        previous_green  previous_blue  start_red  start_green  start_blue  ...  \
# 513          0.984314       0.992157   0.988235     0.984314    0.992157  ...
# 514          0.982591       0.991173   0.988235     0.984314    0.992157  ...
# 515          0.980869       0.990188   0.988235     0.984314    0.992157  ...
# 516          0.979146       0.989204   0.988235     0.984314    0.992157  ...
# 517          0.977424       0.988220   0.988235     0.984314    0.992157  ...
# ...               ...            ...        ...          ...         ...  ...
# 63482        0.184314       0.384314   0.992157     0.992157    0.901961  ...
# 63483        0.180392       0.380392   0.992157     0.992157    0.901961  ...
# 63484        0.172549       0.372549   0.992157     0.992157    0.901961  ...
# 63485        0.168627       0.368627   0.992157     0.992157    0.901961  ...
# 63486        0.160784       0.360784   0.992157     0.992157    0.901961  ...
#
#        middle_red  middle_green  middle_blue  cos_theta_start  \
# 513      0.617762      0.602138     0.783453         1.000000
# 514      0.617762      0.602138     0.783453         1.000000
# 515      0.617762      0.602138     0.783453         1.000000
# 516      0.617762      0.602138     0.783453         0.999999
# 517      0.617762      0.602138     0.783453         0.999999
# ...           ...           ...          ...              ...
# 63482    0.901961      0.949020     1.000000         0.885406
# 63483    0.901961      0.949020     1.000000         0.882164
# 63484    0.901961      0.949020     1.000000         0.875662
# 63485    0.901961      0.949020     1.000000         0.871874
# 63486    0.901961      0.949020     1.000000         0.864615
#
#        cos_theta_middle  cos_theta_previous  cos_theta_end  next_red  \
# 513            0.992929            1.000000       0.777654  0.985037
# 514            0.992968            1.000000       0.777849  0.983437
# 515            0.993007            1.000000       0.778045  0.981838
# 516            0.993046            1.000000       0.778241  0.980238
# 517            0.993086            1.000000       0.778438  0.978639
# ...                 ...                 ...            ...       ...
# 63482          0.921032            0.999903       0.998649  0.125490
# 63483          0.918278            0.999961       0.998995  0.117647
# 63484          0.912832            0.999889       0.999499  0.113725
# 63485          0.909590            0.999953       0.999726  0.105882
# 63486          0.903451            0.999874       0.999944  0.101961
#
#        next_green  next_blue
# 513      0.980869   0.990188
# 514      0.979146   0.989204
# 515      0.977424   0.988220
# 516      0.975702   0.987236
# 517      0.973979   0.986251
# ...           ...        ...
# 63482    0.172549   0.372549
# 63483    0.168627   0.368627
# 63484    0.160784   0.360784
# 63485    0.156863   0.356863
# 63486    0.149020   0.349020
#
# [53039 rows x 23 columns]

# %%
viridis = dataset[dataset.colormap_name == 'perceptually_uniform_sequential.viridis']
viridis.cos_theta_end.describe()
# Out:
# count    255.000000
# mean       0.750950
# std        0.138835
# min        0.556992
# 25%        0.657045
# 50%        0.664889
# 75%        0.881200
# max        1.000000
# Name: cos_theta_end, dtype: float64

# %%
dataset.colormap_name.unique()
# Out:
# array(['sequential.Purples', 'sequential.Purples_r', 'sequential.Blues',
#        'sequential.Blues_r', 'sequential.Greens', 'sequential.Greens_r',
#        'sequential.Oranges', 'sequential.Oranges_r', 'sequential.Reds',
#        'sequential.Reds_r', 'sequential.YlOrBr', 'sequential.YlOrBr_r',
#        'sequential.YlOrRd', 'sequential.YlOrRd_r', 'sequential.OrRd',
#        'sequential.OrRd_r', 'sequential.PuRd', 'sequential.PuRd_r',
#        'sequential.RdPu', 'sequential.RdPu_r', 'sequential.BuPu',
#        'sequential.BuPu_r', 'sequential.GnBu', 'sequential.GnBu_r',
#        'sequential.PuBu', 'sequential.PuBu_r', 'sequential.YlGnBu',
#        'sequential.YlGnBu_r', 'sequential.PuBuGn', 'sequential.PuBuGn_r',
#        'sequential.BuGn', 'sequential.BuGn_r', 'sequential.YlGn',
#        'sequential.YlGn_r', 'perceptually_uniform_sequential.viridis',
#        'perceptually_uniform_sequential.viridis_r',
#        'perceptually_uniform_sequential.plasma',
#        'perceptually_uniform_sequential.plasma_r',
#        'perceptually_uniform_sequential.inferno',
#        'perceptually_uniform_sequential.inferno_r',
#        'perceptually_uniform_sequential.magma',
#        'perceptually_uniform_sequential.magma_r',
#        'perceptually_uniform_sequential.cividis',
#        'perceptually_uniform_sequential.cividis_r', 'sequential_2.pink',
#        'sequential_2.pink_r', 'sequential_2.spring',
#        'sequential_2.spring_r', 'sequential_2.summer',
#        'sequential_2.summer_r', 'sequential_2.autumn',
#        'sequential_2.autumn_r', 'sequential_2.winter',
#        'sequential_2.winter_r', 'sequential_2.cool',
#        'sequential_2.cool_r', 'sequential_2.Wistia',
#        'sequential_2.Wistia_r', 'sequential_2.hot', 'sequential_2.hot_r',
#        'cyclic.twilight', 'cyclic.twilight_r', 'cyclic.twilight_shifted',
#        'cyclic.twilight_shifted_r', 'cyclic.hsv', 'cyclic.hsv_r',
#        'cartomap.Burg_7', 'cartomap.Burg_7_r', 'cartomap.BurgYl_7',
#        'cartomap.BurgYl_7_r', 'cartomap.RedOr_7', 'cartomap.RedOr_7_r',
#        'cartomap.OrYel_7', 'cartomap.OrYel_7_r', 'cartomap.Peach_7',
#        'cartomap.Peach_7_r', 'cartomap.PinkYl_7', 'cartomap.PinkYl_7_r',
#        'cartomap.Mint_7', 'cartomap.Mint_7_r', 'cartomap.BluGrn_7',
#        'cartomap.BluGrn_7_r', 'cartomap.DarkMint_7',
#        'cartomap.DarkMint_7_r', 'cartomap.Emrld_7', 'cartomap.Emrld_7_r',
#        'cartomap.agGrnYl_7', 'cartomap.agGrnYl_7_r', 'cartomap.BluYl_7',
#        'cartomap.BluYl_7_r', 'cartomap.Teal_7', 'cartomap.Teal_7_r',
#        'cartomap.TealGrn_7', 'cartomap.TealGrn_7_r', 'cartomap.Purp_7',
#        'cartomap.Purp_7_r', 'cartomap.PurpOr_7', 'cartomap.PurpOr_7_r',
#        'cartomap.Sunset_7', 'cartomap.Sunset_7_r', 'cartomap.Magenta_7',
#        'cartomap.Magenta_7_r', 'cartomap.SunsetDark_7',
#        'cartomap.SunsetDark_7_r', 'cartomap.agSunset_7',
#        'cartomap.agSunset_7_r', 'cartomap.BrwnYl_7',
#        'cartomap.BrwnYl_7_r', 'colorbrewer.Blues_9',
#        'colorbrewer.Blues_9_r', 'colorbrewer.BuGn_9',
#        'colorbrewer.BuGn_9_r', 'colorbrewer.BuPu_9',
#        'colorbrewer.BuPu_9_r', 'colorbrewer.GnBu_9',
#        'colorbrewer.GnBu_9_r', 'colorbrewer.Greens_9',
#        'colorbrewer.Greens_9_r', 'colorbrewer.OrRd_9',
#        'colorbrewer.OrRd_9_r', 'colorbrewer.Oranges_9',
#        'colorbrewer.Oranges_9_r', 'colorbrewer.PuBu_9',
#        'colorbrewer.PuBu_9_r', 'colorbrewer.PuBuGn_9',
#        'colorbrewer.PuBuGn_9_r', 'colorbrewer.PuRd_9',
#        'colorbrewer.PuRd_9_r', 'colorbrewer.Purples_9',
#        'colorbrewer.Purples_9_r', 'colorbrewer.RdPu_9',
#        'colorbrewer.RdPu_9_r', 'colorbrewer.Reds_9',
#        'colorbrewer.Reds_9_r', 'colorbrewer.YlGn_9',
#        'colorbrewer.YlGn_9_r', 'colorbrewer.YlGnBu_9',
#        'colorbrewer.YlGnBu_9_r', 'colorbrewer.YlOrBr_9',
#        'colorbrewer.YlOrBr_9_r', 'colorbrewer.YlOrRd_9',
#        'colorbrewer.YlOrRd_9_r', 'cmocean.Algae_256',
#        'cmocean.Algae_256_r', 'cmocean.Amp_256', 'cmocean.Amp_256_r',
#        'cmocean.Deep_256', 'cmocean.Deep_256_r', 'cmocean.Dense_256',
#        'cmocean.Dense_256_r', 'cmocean.Haline_256',
#        'cmocean.Haline_256_r', 'cmocean.Ice_256', 'cmocean.Ice_256_r',
#        'cmocean.Matter_256', 'cmocean.Matter_256_r', 'cmocean.Oxy_256',
#        'cmocean.Oxy_256_r', 'cmocean.Phase_256', 'cmocean.Phase_256_r',
#        'cmocean.Solar_256', 'cmocean.Solar_256_r', 'cmocean.Speed_256',
#        'cmocean.Speed_256_r', 'cmocean.Tempo_256', 'cmocean.Tempo_256_r',
#        'cmocean.Thermal_256', 'cmocean.Thermal_256_r',
#        'cmocean.Turbid_256', 'cmocean.Turbid_256_r',
#        'cubehelix.perceptual_rainbow_16',
#        'cubehelix.perceptual_rainbow_16_r', 'mycarta.Cube1_20',
#        'mycarta.Cube1_20_r', 'mycarta.CubeYF_20', 'mycarta.CubeYF_20_r',
#        'mycarta.LinearL_20', 'mycarta.LinearL_20_r',
#        'scientific.Devon_256', 'scientific.Devon_256_r',
#        'scientific.LaJolla_256', 'scientific.LaJolla_256_r',
#        'scientific.Bamako_256', 'scientific.Bamako_256_r',
#        'scientific.Davos_256', 'scientific.Davos_256_r',
#        'scientific.Bilbao_256', 'scientific.Bilbao_256_r',
#        'scientific.Nuuk_256', 'scientific.Nuuk_256_r',
#        'scientific.Oslo_256', 'scientific.Oslo_256_r',
#        'scientific.Hawaii_256', 'scientific.Hawaii_256_r',
#        'scientific.LaPaz_256', 'scientific.LaPaz_256_r',
#        'scientific.Tokyo_256', 'scientific.Tokyo_256_r',
#        'scientific.Buda_256', 'scientific.Buda_256_r',
#        'scientific.Acton_256', 'scientific.Acton_256_r',
#        'scientific.Imola_256', 'scientific.Imola_256_r',
#        'scientific.Batlow_256', 'scientific.Batlow_256_r',
#        'scientific.Oleron_256', 'scientific.Oleron_256_r'], dtype=object)

# %%
def plot_colorramps(colorramp: pd.DataFrame, comparison_ramp: pd.DataFrame=None) ->plt.figure:
    ramp_name = f"{colorramp.colormap_name.unique()[0].split('.')[-1]}"
    figsize = (8, 1)
    comparison_coloramp_ax = None
    if comparison_ramp is not None:
        fig, axes = plt.subplots(figsize=figsize, nrows=2)
        colorramp_ax, comparison_coloramp_ax = axes
    else:
        fig, colorramp_ax = plt.subplots(figsize=figsize)
    plt.subplots_adjust(hspace=0.0, top=.6)

    colorramp_ax.axis(xmin=0, xmax=len(colorramp))
    colorramp_ax.tick_params(left=False, labelleft=False, bottom=False, labelbottom=False)
    for index, color in enumerate(np.array(colorramp[['red', 'green', 'blue']])):
        colorramp_ax.axvspan(index, index + 1, color=color)
    
    colorramp_ax.set_xlabel(f"Model Output {ramp_name.title()}", labelpad=5)
    colorramp_ax.xaxis.set_label_position('top')
    colorramp_ax.spines['bottom'].set_visible(False)
    if not comparison_coloramp_ax:
        return fig

    comparison_coloramp_ax.axis(xmin=0, xmax=len(colorramp))
    comparison_coloramp_ax.tick_params(left=False, labelleft=False, bottom=False, labelbottom=False)
    comparison_coloramp_ax.set_xlabel(f"Comparison {ramp_name.title()}")
    comparison_coloramp_ax.spines['top'].set_visible(False)

    for index, color in enumerate(np.array(comparison_ramp[['red', 'green', 'blue']])):
        comparison_coloramp_ax.axvspan(index, index + 1, color=color)
    return fig


f = plot_colorramps(viridis, viridis)
# plt.tight_layout()
display("Ideal Output")
# Out:
# 'Ideal Output'

# %%
def generate_from_model(label, 
                        red, green, blue, 
                        previous_red, previous_green, previous_blue, 
                        start_red, start_green, start_blue, 
                        middle_red, middle_green, middle_blue,
                        end_red, end_green, end_blue,
                        cos_theta_start, cos_theta_previous, cos_theta_end, 
                        cos_theta_middle
    ):
    
    data = []
    for _ in range(256):
        data.append([
            red, green, blue, 
            previous_red, previous_green, previous_blue, 
            start_red, start_green, start_blue,
            middle_red, middle_green, middle_blue,
            end_red, end_green, end_blue,
            cos_theta_start, cos_theta_previous, cos_theta_end,  cos_theta_middle
            ])
        next_red, next_green, next_blue = xgb_reg.predict(np.array([data[-1]]))[0]

        previous_red = red
        previous_green = green
        previous_blue = blue

        red = next_red
        green = next_green
        blue = next_blue

        rgb_vector = np.array([red, green, blue])
        rgb_magnitude = np.linalg.norm(rgb_vector)

        start_rgb_vector = np.array([start_red, start_green, start_blue])
        start_rgb_magnitude = np.linalg.norm(start_rgb_vector)

        middle_rgb_vector = np.array([middle_red, middle_green, middle_blue])
        middle_rgb_magnitude = np.linalg.norm(middle_rgb_vector)
        
        previous_rgb_vector = np.array([previous_red, previous_green, previous_blue])
        previous_rgb_magnitude = np.linalg.norm(previous_rgb_vector)

        end_rgb_vector = np.array([end_red, end_green, end_blue])
        end_rgb_magnitude = np.linalg.norm(end_rgb_vector)

        cos_theta_start = np.dot(rgb_vector, start_rgb_vector) / (rgb_magnitude * start_rgb_magnitude)
        cos_theta_middle = np.dot(rgb_vector, middle_rgb_vector) / (rgb_magnitude * middle_rgb_magnitude)
        cos_theta_previous = np.dot(rgb_vector, previous_rgb_vector) / (rgb_magnitude * previous_rgb_magnitude)
        cos_theta_end = np.dot(rgb_vector, end_rgb_vector) / (rgb_magnitude * end_rgb_magnitude)
    df = pd.DataFrame(data, columns=dependent_variables)
    df['colormap_name'] = label
    return df


test_name = "perceptually_uniform_sequential.viridis"
# test_name = "scientific.Acton_256_r"
# test_name = "sequential.PuBuGn"
colorramp_df = dataset[dataset.colormap_name == test_name]
label = colorramp_df.colormap_name.unique()[0]
first_row = colorramp_df[dependent_variables].iloc[0].T
data = (generate_from_model(label, **{key: val for key, val in zip(first_row.index, first_row)}))

# %%
data[data[[c for c in data if c != 'colormap_name']] >= 1] = 1
data[data[[c for c in data if c != 'colormap_name']] < 0] = 0
f = plot_colorramps(data, colorramp_df)

# %%
data[data[[c for c in data if c != 'colormap_name']] >= 1] = 1
data[data[[c for c in data if c != 'colormap_name']] < 0] = 0
f = plot_colorramps(data, colorramp_df)

# %%
data.describe()
# Out:
#               red       green        blue  previous_red  previous_green  \
# count  256.000000  256.000000  256.000000    256.000000      256.000000
# mean     0.165000    0.086527    0.200147      0.164331        0.086190
# std      0.012626    0.006910    0.038450      0.016236        0.008756
# min      0.002267    0.001270    0.018570      0.001462        0.000466
# 25%      0.160198    0.084704    0.163480      0.160198        0.084704
# 50%      0.161276    0.085532    0.168876      0.161276        0.085532
# 75%      0.172338    0.086744    0.237888      0.172338        0.086744
# max      0.173823    0.097631    0.239987      0.173823        0.097631
#
#        previous_blue     start_red   start_green    start_blue     end_red  \
# count     256.000000  2.560000e+02  2.560000e+02  2.560000e+02  256.000000
# mean        0.199272  1.462000e-03  4.660000e-04  1.386600e-02    0.735683
# std         0.040101  4.345304e-19  1.086326e-19  3.476243e-18    0.000000
# min         0.013866  1.462000e-03  4.660000e-04  1.386600e-02    0.735683
# 25%         0.163480  1.462000e-03  4.660000e-04  1.386600e-02    0.735683
# 50%         0.166967  1.462000e-03  4.660000e-04  1.386600e-02    0.735683
# 75%         0.237888  1.462000e-03  4.660000e-04  1.386600e-02    0.735683
# max         0.239987  1.462000e-03  4.660000e-04  1.386600e-02    0.735683
#
#           end_green    end_blue    middle_red  middle_green   middle_blue  \
# count  2.560000e+02  256.000000  2.560000e+02  2.560000e+02  2.560000e+02
# mean   2.159060e-01    0.330245  9.883620e-01  9.983640e-01  6.449240e-01
# std    2.780995e-17    0.000000  3.337193e-16  3.337193e-16  2.224796e-16
# min    2.159060e-01    0.330245  9.883620e-01  9.983640e-01  6.449240e-01
# 25%    2.159060e-01    0.330245  9.883620e-01  9.983640e-01  6.449240e-01
# 50%    2.159060e-01    0.330245  9.883620e-01  9.983640e-01  6.449240e-01
# 75%    2.159060e-01    0.330245  9.883620e-01  9.983640e-01  6.449240e-01
# max    2.159060e-01    0.330245  9.883620e-01  9.983640e-01  6.449240e-01
#
#        cos_theta_start  cos_theta_middle  cos_theta_previous  cos_theta_end
# count       256.000000        256.000000          256.000000     256.000000
# mean          0.794243          0.985880            0.894528       0.901607
# std           0.050444          0.017254            0.038879       0.036628
# min           0.691887          0.714310            0.534229       0.515838
# 25%           0.752353          0.985170            0.862256       0.876583
# 50%           0.805017          0.988133            0.897997       0.894377
# 75%           0.841158          0.989351            0.921508       0.929692
# max           0.999275          0.999275            0.948696       0.948715
